# %% [markdown]
# # TCN-VAE (Temporal Convolutional Network - Variational Autoencoder)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from pathlib import Path
import sys
sys.path.append('../../')
from utils.metrics import calculate_anomaly_metrics, format_results

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow.keras.backend as K

# Reproducibilidad
np.random.seed(42)
tf.random.set_seed(42)

# %%
# 1. CARGAR DATOS
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# 2. FEATURES
feature_cols = [
    'sensor_2', 'sensor_3', 'sensor_4', 'sensor_7', 'sensor_8', 'sensor_9', 'sensor_11', 'sensor_12', 'sensor_13', 'sensor_14', 'sensor_15', 'sensor_17', 'sensor_20', 'sensor_21'
]


print(f"Train shape: {train.shape}")
print(f"Test shape: {test.shape}")
print(f"Features: {len(feature_cols)}")
# Out:
# Train shape: (61249, 27)
# Test shape: (41214, 26)
# Features: 14

# %%
# 3. CREAR BASELINE (30% primeros ciclos)
def get_baseline(df, pct=0.3):
    baseline_list = []
    for unit in df['unit_id'].unique():
        unit_data = df[df['unit_id'] == unit]
        cutoff = unit_data['time_cycles'].max() * pct
        baseline_list.append(unit_data[unit_data['time_cycles'] <= cutoff])
    return pd.concat(baseline_list)

baseline = get_baseline(train)

# 4. NORMALIZACIÓN
scaler = StandardScaler()
scaler.fit(baseline[feature_cols].values)

print(f"Baseline samples: {len(baseline)}")
print(f"Features: {len(feature_cols)}")
# Out:
# Baseline samples: 18273
# Features: 14

# %%
# 5. CREAR SECUENCIAS TEMPORALES
window_size = 50  # Ventana de 50 ciclos para TCN

def create_sequences(df, feature_cols, window_size, scaler):
    """
    Crea secuencias temporales para cada unidad.
    Retorna: (sequences, indices) donde indices mapea cada secuencia al índice original
    """
    sequences = []
    indices = []
    
    for unit in df['unit_id'].unique():
        unit_data = df[df['unit_id'] == unit].sort_values('time_cycles')
        values = scaler.transform(unit_data[feature_cols].values)
        
        # Crear ventanas deslizantes
        for i in range(len(values) - window_size + 1):
            sequences.append(values[i:i+window_size])
            # Guardar índice del último punto de la ventana
            indices.append(unit_data.index[i + window_size - 1])
    
    return np.array(sequences), np.array(indices)

# Crear secuencias para baseline
X_baseline, baseline_indices = create_sequences(baseline, feature_cols, window_size, scaler)

print(f"Baseline sequences: {X_baseline.shape}")
print(f"Sequence shape: (samples={X_baseline.shape[0]}, timesteps={X_baseline.shape[1]}, features={X_baseline.shape[2]})")
# Out:
# Baseline sequences: (6175, 50, 14)
# Sequence shape: (samples=6175, timesteps=50, features=14)

# %%
# 6. ARQUITECTURA TCN-VAE
timesteps = window_size
n_features = len(feature_cols)
latent_dim = 16

# Sampling layer para el espacio latente
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.random.normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# ENCODER con TCN (1D Convolutions)
encoder_inputs = layers.Input(shape=(timesteps, n_features))
x = layers.Conv1D(64, 3, activation='relu', padding='same')(encoder_inputs)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling1D(2)(x)
x = layers.Dropout(0.2)(x)

x = layers.Conv1D(128, 3, activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling1D(2)(x)
x = layers.Dropout(0.2)(x)

x = layers.Conv1D(256, 3, activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.GlobalAveragePooling1D()(x)

z_mean = layers.Dense(latent_dim, name='z_mean')(x)
z_log_var = layers.Dense(latent_dim, name='z_log_var')(x)
z = Sampling()([z_mean, z_log_var])

encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name='encoder')

# DECODER
latent_inputs = layers.Input(shape=(latent_dim,))
# Calcular la dimensión después de los poolings
pooled_timesteps = timesteps // 4  # 2 poolings de factor 2

x = layers.Dense(pooled_timesteps * 256, activation='relu')(latent_inputs)
x = layers.Reshape((pooled_timesteps, 256))(x)

x = layers.Conv1D(256, 3, activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.UpSampling1D(2)(x)
x = layers.Dropout(0.2)(x)

x = layers.Conv1D(128, 3, activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.UpSampling1D(2)(x)
x = layers.Dropout(0.2)(x)

x = layers.Conv1D(64, 3, activation='relu', padding='same')(x)
# Add zero padding to match original timesteps if needed
x = layers.ZeroPadding1D(padding=(0, timesteps - pooled_timesteps * 4))(x)
decoder_outputs = layers.Conv1D(n_features, 3, padding='same')(x)

decoder = keras.Model(latent_inputs, decoder_outputs, name='decoder')

encoder.summary()
print('\n')
decoder.summary()
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 50, 14)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 50, 64)    │      2,752 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 64)    │        256 │ conv1d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_2     │ (None, 25, 64)    │          0 │ batch_normalizat… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 25, 64)    │          0 │ max_pooling1d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_8 (Conv1D)   │ (None, 25, 128)   │     24,704 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 25, 128)   │        512 │ conv1d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_3     │ (None, 12, 128)   │          0 │ batch_normalizat… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 12, 128)   │          0 │ max_pooling1d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_9 (Conv1D)   │ (None, 12, 256)   │     98,560 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 256)   │      1,024 │ conv1d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 16)        │      4,112 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 16)        │      4,112 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling_1          │ (None, 16)        │          0 │ z_mean[0][0],     │
# │ (Sampling)          │                   │            │ z_log_var[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 136,032 (531.38 KB)
#  Trainable params: 135,136 (527.88 KB)
#  Non-trainable params: 896 (3.50 KB)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3072)           │        52,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 12, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 12, 256)        │       196,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 12, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling1d_2 (UpSampling1D)  │ (None, 24, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 24, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 24, 128)        │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 24, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling1d_3 (UpSampling1D)  │ (None, 48, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 48, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_12 (Conv1D)              │ (None, 48, 64)         │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ zero_padding1d_1                │ (None, 50, 64)         │             0 │
# │ (ZeroPadding1D)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_13 (Conv1D)              │ (None, 50, 14)         │         2,702 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 376,398 (1.44 MB)
#  Trainable params: 375,630 (1.43 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
# 7. MODELO VAE COMPLETO
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        # Unpack the data - fit() passes (x, y) as a tuple
        if isinstance(data, tuple):
            data = data[0]  # We only need the input, target is the same for autoencoders
        
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            
            # Reconstruction loss (MSE)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    tf.square(data - reconstruction), axis=(1, 2)
                )
            )
            
            # KL divergence loss
            kl_loss = -0.5 * tf.reduce_mean(
                tf.reduce_sum(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=1)
            )
            
            total_loss = reconstruction_loss + 0.01 * kl_loss  # Beta = 0.01
        
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        
        return {
            "total_loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }
    
    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        return self.decoder(z)

vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001))

print("VAE model created successfully")
# Out:
# VAE model created successfully

# %%
# 8. ENTRENAR EN BASELINE
early_stop = keras.callbacks.EarlyStopping(
    monitor='total_loss',
    mode='min',
    patience=15,
    restore_best_weights=True
)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='total_loss',
    mode='min',
    factor=0.5,
    patience=5,
    min_lr=1e-6
)

history = vae.fit(
    X_baseline, X_baseline,
    epochs=100,
    batch_size=64,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - kl_loss: 15.5832 - reconstruction_loss: 687.2531 - total_loss: 687.4090 - learning_rate: 0.0010
# Epoch 2/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 41.1394 - reconstruction_loss: 661.1494 - total_loss: 661.5608 - learning_rate: 0.0010
# Epoch 3/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 51.2039 - reconstruction_loss: 635.7758 - total_loss: 636.2878 - learning_rate: 0.0010
# Epoch 4/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 52.2630 - reconstruction_loss: 625.4247 - total_loss: 625.9474 - learning_rate: 0.0010
# Epoch 5/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 55.9598 - reconstruction_loss: 607.8482 - total_loss: 608.4077 - learning_rate: 0.0010
# Epoch 6/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - kl_loss: 60.0816 - reconstruction_loss: 592.2333 - total_loss: 592.8340 - learning_rate: 0.0010
# Epoch 7/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - kl_loss: 61.2907 - reconstruction_loss: 585.2662 - total_loss: 585.8790 - learning_rate: 0.0010
# Epoch 8/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 62.5934 - reconstruction_loss: 577.5417 - total_loss: 578.1677 - learning_rate: 0.0010
# Epoch 9/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 63.8872 - reconstruction_loss: 562.6784 - total_loss: 563.3172 - learning_rate: 0.0010
# Epoch 10/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 66.9714 - reconstruction_loss: 549.1710 - total_loss: 549.8408 - learning_rate: 0.0010
# Epoch 11/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 67.8471 - reconstruction_loss: 538.3968 - total_loss: 539.0753 - learning_rate: 0.0010
# Epoch 12/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 69.1688 - reconstruction_loss: 526.9435 - total_loss: 527.6353 - learning_rate: 0.0010
# Epoch 13/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 70.5105 - reconstruction_loss: 517.8881 - total_loss: 518.5931 - learning_rate: 0.0010
# Epoch 14/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 71.5337 - reconstruction_loss: 509.1027 - total_loss: 509.8181 - learning_rate: 0.0010
# Epoch 15/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 71.6954 - reconstruction_loss: 502.8838 - total_loss: 503.6006 - learning_rate: 0.0010
# Epoch 16/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 74.3475 - reconstruction_loss: 493.1489 - total_loss: 493.8924 - learning_rate: 0.0010
# Epoch 17/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 75.4514 - reconstruction_loss: 485.9958 - total_loss: 486.7502 - learning_rate: 0.0010
# Epoch 18/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 77.8421 - reconstruction_loss: 479.7331 - total_loss: 480.5113 - learning_rate: 0.0010
# Epoch 19/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - kl_loss: 78.0993 - reconstruction_loss: 471.3663 - total_loss: 472.1473 - learning_rate: 0.0010
# Epoch 20/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 77.7063 - reconstruction_loss: 464.2266 - total_loss: 465.0037 - learning_rate: 0.0010
# Epoch 21/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - kl_loss: 78.6397 - reconstruction_loss: 458.2109 - total_loss: 458.9973 - learning_rate: 0.0010
# Epoch 22/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - kl_loss: 79.9866 - reconstruction_loss: 450.8628 - total_loss: 451.6627 - learning_rate: 0.0010
# Epoch 23/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - kl_loss: 81.9279 - reconstruction_loss: 445.1003 - total_loss: 445.9196 - learning_rate: 0.0010
# Epoch 24/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - kl_loss: 82.5944 - reconstruction_loss: 438.9251 - total_loss: 439.7510 - learning_rate: 0.0010
# Epoch 25/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 81.2820 - reconstruction_loss: 439.7041 - total_loss: 440.5169 - learning_rate: 0.0010
# Epoch 26/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 81.8715 - reconstruction_loss: 429.6375 - total_loss: 430.4562 - learning_rate: 0.0010
# Epoch 27/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 83.3763 - reconstruction_loss: 422.6021 - total_loss: 423.4358 - learning_rate: 0.0010
# Epoch 28/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 84.4113 - reconstruction_loss: 418.3430 - total_loss: 419.1871 - learning_rate: 0.0010
# Epoch 29/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 83.6509 - reconstruction_loss: 413.9396 - total_loss: 414.7761 - learning_rate: 0.0010
# Epoch 30/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 84.2198 - reconstruction_loss: 410.8844 - total_loss: 411.7267 - learning_rate: 0.0010
# Epoch 31/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 85.0035 - reconstruction_loss: 407.7963 - total_loss: 408.6463 - learning_rate: 0.0010
# Epoch 32/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 85.6993 - reconstruction_loss: 404.4538 - total_loss: 405.3109 - learning_rate: 0.0010
# Epoch 33/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 85.7888 - reconstruction_loss: 403.0301 - total_loss: 403.8880 - learning_rate: 0.0010
# Epoch 34/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 85.1360 - reconstruction_loss: 403.0732 - total_loss: 403.9246 - learning_rate: 0.0010
# Epoch 35/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 85.7595 - reconstruction_loss: 396.2614 - total_loss: 397.1190 - learning_rate: 0.0010
# Epoch 36/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 86.0404 - reconstruction_loss: 395.6148 - total_loss: 396.4754 - learning_rate: 0.0010
# Epoch 37/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 86.2479 - reconstruction_loss: 393.5829 - total_loss: 394.4455 - learning_rate: 0.0010
# Epoch 38/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 85.7758 - reconstruction_loss: 393.5453 - total_loss: 394.4031 - learning_rate: 0.0010
# Epoch 39/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 86.4841 - reconstruction_loss: 393.3669 - total_loss: 394.2317 - learning_rate: 0.0010
# Epoch 40/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 86.7856 - reconstruction_loss: 388.3073 - total_loss: 389.1751 - learning_rate: 0.0010
# Epoch 41/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 87.3843 - reconstruction_loss: 386.2238 - total_loss: 387.0977 - learning_rate: 0.0010
# Epoch 42/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 87.6261 - reconstruction_loss: 377.9247 - total_loss: 378.8009 - learning_rate: 0.0010
# Epoch 43/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 88.3331 - reconstruction_loss: 365.1414 - total_loss: 366.0247 - learning_rate: 0.0010
# Epoch 44/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 90.7720 - reconstruction_loss: 359.2887 - total_loss: 360.1964 - learning_rate: 0.0010
# Epoch 45/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 92.1717 - reconstruction_loss: 355.8994 - total_loss: 356.8211 - learning_rate: 0.0010
# Epoch 46/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 91.6914 - reconstruction_loss: 355.9857 - total_loss: 356.9027 - learning_rate: 0.0010
# Epoch 47/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 92.0524 - reconstruction_loss: 357.0787 - total_loss: 357.9992 - learning_rate: 0.0010
# Epoch 48/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 91.1578 - reconstruction_loss: 355.1422 - total_loss: 356.0536 - learning_rate: 0.0010
# Epoch 49/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 92.5399 - reconstruction_loss: 345.1522 - total_loss: 346.0776 - learning_rate: 0.0010
# Epoch 50/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 92.9598 - reconstruction_loss: 343.3088 - total_loss: 344.2383 - learning_rate: 0.0010
# Epoch 51/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - kl_loss: 93.2744 - reconstruction_loss: 338.4499 - total_loss: 339.3825 - learning_rate: 0.0010
# Epoch 52/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 92.8411 - reconstruction_loss: 334.6771 - total_loss: 335.6054 - learning_rate: 0.0010
# Epoch 53/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 92.3744 - reconstruction_loss: 331.0581 - total_loss: 331.9818 - learning_rate: 0.0010
# Epoch 54/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 93.0155 - reconstruction_loss: 328.6555 - total_loss: 329.5856 - learning_rate: 0.0010
# Epoch 55/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 94.1748 - reconstruction_loss: 324.4297 - total_loss: 325.3715 - learning_rate: 0.0010
# Epoch 56/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 94.4982 - reconstruction_loss: 322.1466 - total_loss: 323.0916 - learning_rate: 0.0010
# Epoch 57/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 94.0133 - reconstruction_loss: 320.8390 - total_loss: 321.7791 - learning_rate: 0.0010
# Epoch 58/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 94.2750 - reconstruction_loss: 319.7114 - total_loss: 320.6543 - learning_rate: 0.0010
# Epoch 59/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 94.9984 - reconstruction_loss: 316.7877 - total_loss: 317.7376 - learning_rate: 0.0010
# Epoch 60/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 95.1846 - reconstruction_loss: 315.6633 - total_loss: 316.6151 - learning_rate: 0.0010
# Epoch 61/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 95.0089 - reconstruction_loss: 316.8513 - total_loss: 317.8014 - learning_rate: 0.0010
# Epoch 62/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 93.9874 - reconstruction_loss: 318.2615 - total_loss: 319.2014 - learning_rate: 0.0010
# Epoch 63/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 93.6268 - reconstruction_loss: 318.2707 - total_loss: 319.2069 - learning_rate: 0.0010
# Epoch 64/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 94.5028 - reconstruction_loss: 316.2575 - total_loss: 317.2026 - learning_rate: 0.0010
# Epoch 65/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 94.8267 - reconstruction_loss: 310.2727 - total_loss: 311.2210 - learning_rate: 0.0010
# Epoch 66/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 97.3349 - reconstruction_loss: 298.5776 - total_loss: 299.5510 - learning_rate: 0.0010
# Epoch 67/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 98.6808 - reconstruction_loss: 297.8384 - total_loss: 298.8253 - learning_rate: 0.0010
# Epoch 68/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 98.7241 - reconstruction_loss: 297.3872 - total_loss: 298.3744 - learning_rate: 0.0010
# Epoch 69/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 97.2560 - reconstruction_loss: 296.3297 - total_loss: 297.3022 - learning_rate: 0.0010
# Epoch 70/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 95.9215 - reconstruction_loss: 297.4081 - total_loss: 298.3674 - learning_rate: 0.0010
# Epoch 71/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 94.8280 - reconstruction_loss: 295.3685 - total_loss: 296.3169 - learning_rate: 0.0010
# Epoch 72/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 96.2114 - reconstruction_loss: 292.0254 - total_loss: 292.9876 - learning_rate: 0.0010
# Epoch 73/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 96.9355 - reconstruction_loss: 290.4907 - total_loss: 291.4600 - learning_rate: 0.0010
# Epoch 74/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 97.1358 - reconstruction_loss: 287.5707 - total_loss: 288.5420 - learning_rate: 0.0010
# Epoch 75/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 96.9570 - reconstruction_loss: 284.2195 - total_loss: 285.1891 - learning_rate: 0.0010
# Epoch 76/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 97.4533 - reconstruction_loss: 280.6049 - total_loss: 281.5795 - learning_rate: 0.0010
# Epoch 77/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 97.5135 - reconstruction_loss: 282.0171 - total_loss: 282.9922 - learning_rate: 0.0010
# Epoch 78/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 98.1887 - reconstruction_loss: 277.2316 - total_loss: 278.2136 - learning_rate: 0.0010
# Epoch 79/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 98.3879 - reconstruction_loss: 272.9495 - total_loss: 273.9334 - learning_rate: 0.0010
# Epoch 80/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 98.5953 - reconstruction_loss: 269.1976 - total_loss: 270.1836 - learning_rate: 0.0010
# Epoch 81/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 99.6000 - reconstruction_loss: 263.6931 - total_loss: 264.6891 - learning_rate: 0.0010
# Epoch 82/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 101.2143 - reconstruction_loss: 260.3376 - total_loss: 261.3497 - learning_rate: 0.0010
# Epoch 83/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 101.2260 - reconstruction_loss: 257.1811 - total_loss: 258.1933 - learning_rate: 0.0010
# Epoch 84/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 101.6240 - reconstruction_loss: 253.7158 - total_loss: 254.7321 - learning_rate: 0.0010
# Epoch 85/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 101.4501 - reconstruction_loss: 253.0608 - total_loss: 254.0753 - learning_rate: 0.0010
# Epoch 86/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 101.8696 - reconstruction_loss: 248.1284 - total_loss: 249.1470 - learning_rate: 0.0010
# Epoch 87/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 102.4512 - reconstruction_loss: 246.8597 - total_loss: 247.8842 - learning_rate: 0.0010
# Epoch 88/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 102.2929 - reconstruction_loss: 246.4932 - total_loss: 247.5162 - learning_rate: 0.0010
# Epoch 89/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - kl_loss: 101.4637 - reconstruction_loss: 245.9392 - total_loss: 246.9539 - learning_rate: 0.0010
# Epoch 90/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - kl_loss: 100.7459 - reconstruction_loss: 243.2339 - total_loss: 244.2413 - learning_rate: 0.0010
# Epoch 91/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 100.5707 - reconstruction_loss: 240.5802 - total_loss: 241.5860 - learning_rate: 0.0010
# Epoch 92/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - kl_loss: 101.0025 - reconstruction_loss: 238.2950 - total_loss: 239.3051 - learning_rate: 0.0010
# Epoch 93/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - kl_loss: 100.9679 - reconstruction_loss: 235.7072 - total_loss: 236.7168 - learning_rate: 0.0010
# Epoch 94/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 100.6380 - reconstruction_loss: 233.5375 - total_loss: 234.5439 - learning_rate: 0.0010
# Epoch 95/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 100.6673 - reconstruction_loss: 230.2648 - total_loss: 231.2714 - learning_rate: 0.0010
# Epoch 96/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - kl_loss: 100.3057 - reconstruction_loss: 227.5389 - total_loss: 228.5420 - learning_rate: 0.0010
# Epoch 97/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - kl_loss: 100.6517 - reconstruction_loss: 225.2253 - total_loss: 226.2319 - learning_rate: 0.0010
# Epoch 98/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 101.0665 - reconstruction_loss: 223.6045 - total_loss: 224.6152 - learning_rate: 0.0010
# Epoch 99/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 101.1661 - reconstruction_loss: 223.6650 - total_loss: 224.6766 - learning_rate: 0.0010
# Epoch 100/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 100.2069 - reconstruction_loss: 226.0770 - total_loss: 227.0791 - learning_rate: 0.0010

# %%
# 9. CALCULAR ERROR EN BASELINE Y DEFINIR UMBRAL
X_baseline_reconstructed = vae.predict(X_baseline)
baseline_errors = np.mean(np.mean((X_baseline - X_baseline_reconstructed)**2, axis=2), axis=1)

# Umbral: percentil 99 del baseline
threshold = np.percentile(baseline_errors, 99)
print(f"Umbral (p99): {threshold:.6f}")
print(f"Error medio baseline: {baseline_errors.mean():.6f}")
print(f"Error std baseline: {baseline_errors.std():.6f}")
# Out:
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Umbral (p99): 0.760455
# Error medio baseline: 0.433731
# Error std baseline: 0.133443

# %%
# 10. DETECTAR ANOMALÍAS EN TRAIN
X_train, train_indices = create_sequences(train, feature_cols, window_size, scaler)
X_train_reconstructed = vae.predict(X_train)

# Error de reconstrucción para cada secuencia
sequence_errors = np.mean(np.mean((X_train - X_train_reconstructed)**2, axis=2), axis=1)

# Inicializar columnas
train['reconstruction_error'] = 0.0
train['is_anomaly'] = 0

# Asignar errores a los índices correspondientes
for idx, error in zip(train_indices, sequence_errors):
    train.loc[idx, 'reconstruction_error'] = error
    train.loc[idx, 'is_anomaly'] = int(error > threshold)

# Propagar valores para las primeras ventanas (que no tienen secuencia)
for unit in train['unit_id'].unique():
    unit_mask = train['unit_id'] == unit
    unit_data = train[unit_mask].sort_values('time_cycles')
    
    # Encontrar primer valor no-cero
    first_valid_idx = unit_data[unit_data['reconstruction_error'] > 0].index
    if len(first_valid_idx) > 0:
        first_error = train.loc[first_valid_idx[0], 'reconstruction_error']
        # Asignar a las primeras filas
        early_indices = unit_data[unit_data['reconstruction_error'] == 0].index
        train.loc[early_indices, 'reconstruction_error'] = first_error
        train.loc[early_indices, 'is_anomaly'] = int(first_error > threshold)

print(f"Total sequences: {len(sequence_errors)}")
print(f"Anomalous sequences: {(sequence_errors > threshold).sum()}")
# Out:
#   30/1533 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step
# 2025-11-21 11:25:23.414156: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 137334400 exceeds 10% of free system memory.
# 1533/1533 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step
# 2025-11-21 11:25:29.925603: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 137334400 exceeds 10% of free system memory.
# Total sequences: 49048
# Anomalous sequences: 40207

# %%
# 11. MÉTRICAS
metrics = calculate_anomaly_metrics(train)
metrics['method'] = 'TCN-VAE'
metrics['dataset'] = 'FD001'
format_results(metrics)
# Out:
# ============================================================
# 📊 TCN-VAE - FD001
# ============================================================
# Cobertura: 100.0% (249/249 unidades)
# RUL promedio 1ª detección: 176.2 ciclos
# Detección al 28.2% del ciclo
# Detecciones tempranas (RUL>50): 247
# Falsos positivos (RUL>150): 60.2%
# % anomalías totales: 67.6%
# ============================================================

# %%
# 12. VISUALIZACIÓN
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# a) Historia del entrenamiento
axes[0, 0].plot(history.history['total_loss'], label='Total Loss')
axes[0, 0].plot(history.history['reconstruction_loss'], label='Reconstruction Loss', alpha=0.7)
axes[0, 0].plot(history.history['kl_loss'], label='KL Loss', alpha=0.7)
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].set_title('Training History')
axes[0, 0].legend()
axes[0, 0].grid(alpha=0.3)

# b) Distribución de errores
axes[0, 1].hist(baseline_errors, bins=50, alpha=0.7, label='Baseline', edgecolor='black')
axes[0, 1].hist(train['reconstruction_error'], bins=50, alpha=0.7, label='All data', edgecolor='black')
axes[0, 1].axvline(threshold, color='r', linestyle='--', label=f'Threshold={threshold:.6f}')
axes[0, 1].set_xlabel('Reconstruction Error')
axes[0, 1].set_ylabel('Frequency')
axes[0, 1].set_title('Error Distribution')
axes[0, 1].legend()
axes[0, 1].grid(alpha=0.3)

# c) Evolución temporal ejemplo (unidad 1)
unit_1 = train[train['unit_id'] == 1]
axes[0, 2].plot(unit_1['time_cycles'], unit_1['reconstruction_error'], label='Error', alpha=0.7)
axes[0, 2].axhline(threshold, color='r', linestyle='--', label='Threshold')
axes[0, 2].scatter(unit_1[unit_1['is_anomaly']==1]['time_cycles'], 
                   unit_1[unit_1['is_anomaly']==1]['reconstruction_error'], 
                   color='red', s=50, label='Anomalies', zorder=3)
axes[0, 2].set_xlabel('Cycles')
axes[0, 2].set_ylabel('Reconstruction Error')
axes[0, 2].set_title('Unit 1 - Temporal Evolution')
axes[0, 2].legend()
axes[0, 2].grid(alpha=0.3)

# d) Error vs RUL
axes[1, 0].scatter(train['RUL'], train['reconstruction_error'], alpha=0.3, s=10)
axes[1, 0].axhline(threshold, color='r', linestyle='--', label='Threshold')
axes[1, 0].set_xlabel('RUL')
axes[1, 0].set_ylabel('Reconstruction Error')
axes[1, 0].set_title('Reconstruction Error vs RUL')
axes[1, 0].legend()
axes[1, 0].grid(alpha=0.3)

# e) Evolución temporal para múltiples unidades
for unit_id in [1, 5, 10, 20]:
    unit_data = train[train['unit_id'] == unit_id]
    axes[1, 1].plot(unit_data['time_cycles'], unit_data['reconstruction_error'], 
                    label=f'Unit {unit_id}', alpha=0.7)
axes[1, 1].axhline(threshold, color='r', linestyle='--', label='Threshold', linewidth=2)
axes[1, 1].set_xlabel('Cycles')
axes[1, 1].set_ylabel('Reconstruction Error')
axes[1, 1].set_title('Multiple Units - Error Evolution')
axes[1, 1].legend()
axes[1, 1].grid(alpha=0.3)

# f) Tasa de anomalías por RUL bin
train['rul_bin'] = pd.cut(train['RUL'], bins=[0, 50, 100, 150, 200, 300], 
                          labels=['0-50', '50-100', '100-150', '150-200', '>200'])
anomaly_rate = train.groupby('rul_bin')['is_anomaly'].mean() * 100
axes[1, 2].bar(range(len(anomaly_rate)), anomaly_rate.values, edgecolor='black')
axes[1, 2].set_xticks(range(len(anomaly_rate)))
axes[1, 2].set_xticklabels(anomaly_rate.index, rotation=45)
axes[1, 2].set_xlabel('RUL Range')
axes[1, 2].set_ylabel('Anomaly Rate (%)')
axes[1, 2].set_title('Anomaly Rate by RUL Range')
axes[1, 2].grid(alpha=0.3, axis='y')

plt.tight_layout()
plt.savefig('./outputs/tcn_vae_analysis.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_130500/2279222561.py:61: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   anomaly_rate = train.groupby('rul_bin')['is_anomaly'].mean() * 100

# %%
# 13. VISUALIZAR ESPACIO LATENTE
# Obtener representación latente del baseline
z_mean, z_log_var, z = encoder.predict(X_baseline)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Primeras 2 dimensiones del espacio latente
axes[0].scatter(z_mean[:, 0], z_mean[:, 1], alpha=0.5, s=10)
axes[0].set_xlabel('Latent Dimension 1')
axes[0].set_ylabel('Latent Dimension 2')
axes[0].set_title('Latent Space (Baseline)')
axes[0].grid(alpha=0.3)

# Distribución de varianzas
axes[1].hist(np.exp(z_log_var).flatten(), bins=50, edgecolor='black')
axes[1].set_xlabel('Variance')
axes[1].set_ylabel('Frequency')
axes[1].set_title('Latent Space Variance Distribution')
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.savefig('./outputs/tcn_vae_latent_space.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# 14. VISUALIZAR EJEMPLO DE RECONSTRUCCIÓN
# Seleccionar una secuencia anómala
anomalous_idx = np.where(sequence_errors > threshold)[0][0]
original_seq = X_train[anomalous_idx]
reconstructed_seq = X_train_reconstructed[anomalous_idx]

fig, axes = plt.subplots(3, 5, figsize=(20, 10))
axes = axes.flatten()

for i, feature in enumerate(feature_cols):
    axes[i].plot(original_seq[:, i], label='Original', linewidth=2)
    axes[i].plot(reconstructed_seq[:, i], label='Reconstructed', linestyle='--', linewidth=2)
    axes[i].set_title(feature)
    axes[i].legend()
    axes[i].grid(alpha=0.3)

plt.suptitle(f'Sequence Reconstruction (Error={sequence_errors[anomalous_idx]:.6f})', fontsize=14)
plt.tight_layout()
plt.savefig('./outputs/tcn_vae_sequence_reconstruction.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# 15. GUARDAR RESULTADOS
output_dir = Path('./outputs')
output_dir.mkdir(exist_ok=True)

# Anomalías detectadas
train[['unit_id', 'time_cycles', 'RUL', 'reconstruction_error', 'is_anomaly']].to_csv(
    output_dir / 'tcn_vae_anomalies.csv', index=False
)

# Métricas
pd.DataFrame([metrics]).to_csv(
    output_dir / 'tcn_vae_metrics.csv', index=False
)

print("\n✅ Resultados guardados en ./outputs/")
print(f"   - tcn_vae_anomalies.csv")
print(f"   - tcn_vae_metrics.csv")
print(f"   - tcn_vae_analysis.png")
print(f"   - tcn_vae_latent_space.png")
print(f"   - tcn_vae_sequence_reconstruction.png")
print(f"   - tcn_vae_model.keras")
# Out:
# ✅ Resultados guardados en ./outputs/
#    - tcn_vae_anomalies.csv
#    - tcn_vae_metrics.csv
#    - tcn_vae_analysis.png
#    - tcn_vae_latent_space.png
#    - tcn_vae_sequence_reconstruction.png
#    - tcn_vae_model.keras
